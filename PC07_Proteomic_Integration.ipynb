# %% [markdown]
# <a href="https://colab.research.google.com/github/biopharma26/PracticeNotebooks/blob/main/PC07_Proteomic_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PC07 — Proteomic Integration
#
# Normalize and align protein-abundance features with patient-level transcriptomic and clinical data.

# %%
# @title Colab setup
# !pip -q install pandas numpy matplotlib seaborn scikit-learn scipy statsmodels lifelines networkx umap-learn openpyxl requests

import os, warnings, numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
warnings.filterwarnings("ignore")
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
print("Environment ready.")
# Out:
# Environment ready.

# %%
proteins=["AR","PTEN","AKT1","RB1","TP53","MYC"]
prot=pd.DataFrame(np.random.normal(0,1,(20,len(proteins))), columns=proteins,
                  index=[f"P{i:03d}" for i in range(1,21)])
rna=pd.DataFrame(np.random.normal(0,1,(20,len(proteins))), columns=proteins,index=prot.index)
display(prot.head())
# Out:
#             AR      PTEN      AKT1       RB1      TP53       MYC
# P001  0.496714 -0.138264  0.647689  1.523030 -0.234153 -0.234137
# P002  1.579213  0.767435 -0.469474  0.542560 -0.463418 -0.465730
# P003  0.241962 -1.913280 -1.724918 -0.562288 -1.012831  0.314247
# P004 -0.908024 -1.412304  1.465649 -0.225776  0.067528 -1.424748
# P005 -0.544383  0.110923 -1.150994  0.375698 -0.600639 -0.291694

# %%
# RNA–protein concordance
rows=[]
for g in proteins:
    r,p=__import__("scipy.stats",fromlist=["pearsonr"]).pearsonr(rna[g],prot[g])
    rows.append([g,r,p])
rp=pd.DataFrame(rows,columns=["feature","RNA_protein_r","p"])
display(rp)
# Out:
#   feature  RNA_protein_r         p
# 0      AR      -0.226186  0.337605
# 1    PTEN       0.271750  0.246446
# 2    AKT1       0.165311  0.486112
# 3     RB1      -0.255547  0.276843
# 4    TP53      -0.178106  0.452493
# 5     MYC       0.191080  0.419673
